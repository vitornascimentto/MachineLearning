# %%
from operator import methodcaller
from functools import partial

import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn import metrics
from minisom import MiniSom 
from rx import Observable

# %%
df = pd.read_csv('Admission_Predict_Ver1.1.csv')
df.head(10)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
# 5           6        330          115                  5  4.5   3.0  9.34
# 6           7        321          109                  3  3.0   4.0  8.20
# 7           8        308          101                  2  3.0   4.0  7.90
# 8           9        302          102                  1  2.0   1.5  8.00
# 9          10        323          108                  3  3.5   3.0  8.60
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65
# 5         1              0.90
# 6         1              0.75
# 7         0              0.68
# 8         0              0.50
# 9         0              0.45

# %%
list(df)
# Out:
# ['Serial No.',
#  'GRE Score',
#  'TOEFL Score',
#  'University Rating',
#  'SOP',
#  'LOR ',
#  'CGPA',
#  'Research',
#  'Chance of Admit ']

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
df.drop(['Serial No.'], axis=1, inplace=True)

# %%
sum(df.isnull().sum(), df.isna().sum())
# Out:
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# 50%      8.560000    1.000000           0.72000
# 75%      9.040000    1.000000           0.82000
# max      9.920000    1.000000           0.97000

# %%
df = df.apply(lambda col: col / col.max())

# %%
df.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean     0.930800     0.893267           0.622800    0.674800    0.69680
# std      0.033221     0.050682           0.228702    0.198201    0.18509
# min      0.852941     0.766667           0.200000    0.200000    0.20000
# 25%      0.905882     0.858333           0.400000    0.500000    0.60000
# 50%      0.932353     0.891667           0.600000    0.700000    0.70000
# 75%      0.955882     0.933333           0.800000    0.800000    0.80000
# max      1.000000     1.000000           1.000000    1.000000    1.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000        500.000000
# mean     0.864560    0.560000          0.744062
# std      0.060969    0.496884          0.145506
# min      0.685484    0.000000          0.350515
# 25%      0.819304    0.000000          0.649485
# 50%      0.862903    1.000000          0.742268
# 75%      0.911290    1.000000          0.845361
# max      1.000000    1.000000          1.000000

# %%
X = df['Chance of Admit '].astype('int8')
df.drop('Chance of Admit ', axis=1, inplace=True)

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'random')
    kmeans.fit(df)
    print (i,kmeans.inertia_)
    wcss.append(kmeans.inertia_)  
plt.plot(range(1, 11), wcss)
plt.title('O Metodo Elbow')
plt.xlabel('Numero de Clusters')
plt.ylabel('WSS') #within cluster sum of squares
plt.show()
# Out:
# 1 189.68482438402347
# 2 55.16713659014759
# 3 37.76321220874265
# 4 27.31229927725441
# 5 23.989140221301646
# 6 20.719435200122078
# 7 19.126913856990285
# 8 17.343948697411655
# 9 16.03572821862766
# 10 15.63870730882609

# %%
kmeans = KMeans(n_clusters=2, random_state=20)

y_pred = kmeans.fit_predict(df[['GRE Score',
 'TOEFL Score',
 'University Rating',
 'SOP',
 'LOR ',
 'CGPA',
 'Research']])

# %%
metrics.fowlkes_mallows_score(X, y_pred)
# Out:
# 0.7046736922611005

# %%
y_pred = kmeans.fit_predict(df[['GRE Score', 'TOEFL Score', 'SOP','LOR ','CGPA']])

# %%
metrics.fowlkes_mallows_score(X, y_pred)
# Out:
# 0.7010164994987658

# %%
y_pred = kmeans.fit_predict(df[['GRE Score', 'TOEFL Score']])
metrics.fowlkes_mallows_score(X, y_pred)
# Out:
# 0.7049416665673434

# %%
plt.scatter(df['GRE Score'], df['TOEFL Score'],  c=y_pred)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['SOP'], df['LOR '], df['CGPA'], c=y_pred, cmap=plt.cm.viridis)
ax.set_xlabel('SOP')
ax.set_ylabel('LOR ')
ax.set_zlabel('CGPA')
# Out:
# Text(0.5, 0, 'CGPA')

# %%
# SOM
data = df[['GRE Score', 'TOEFL Score', 'SOP', 'LOR ','CGPA','University Rating','Research']].values

# %%
som = MiniSom(20, 20, 7, sigma=0.5, learning_rate=0.7)
som.train_random(data, 1000)

# %%
qnt = som.quantization(data)
qnt[1]
# Out:
# array([0.40023355, 0.38951977, 0.32365096, 0.39144716, 0.38218383,
#        0.33318724, 0.41596685])

# %%
pesos = som.distance_map()

# %%
def _(x, ind):
    markers = ['o', 's']
    colors = ['b', 'y']

    win = som.winner(x)

    plt.plot(win[0], win[1], markers[X[ind]], markeredgecolor = colors[X[ind]], markersize=10, markerfacecolor='None', markeredgewidth=2)

data_test = data[: 1000]
plt.imshow(som.distance_map().T, cmap=plt.cm.gray)
[*map(_, data_test, range(len(data_test)))]
plt.show()

# %%
# Hierarquical

Y = df[['GRE Score', 'TOEFL Score', 'SOP', 'LOR ','CGPA','University Rating','Research']].values

# %%
hiec_clust = AgglomerativeClustering(n_clusters=2, linkage='single')
y_pred = hiec_clust.fit_predict(Y)
metrics.fowlkes_mallows_score(X, y_pred)
# Out:
# 0.7046736922611005

# %%
Y = df[['GRE Score', 'TOEFL Score', 'SOP', 'LOR ','CGPA']].values

# %%
hiec_clust = AgglomerativeClustering(n_clusters=2, linkage='single')
y_pred = hiec_clust.fit_predict(Y)
metrics.fowlkes_mallows_score(X, y_pred)
# Out:
# 0.9879845694735189

# %%
plt.scatter(Y[:, 0], Y[:, 1], c=y_pred, cmap=plt.cm.viridis)

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['SOP'], df['LOR '], df['CGPA'], c=y_pred, cmap=plt.cm.viridis)
ax.set_xlabel('SOP')
ax.set_ylabel('LOR ')
ax.set_zlabel('CGPA')
# Out:
# Text(0.5, 0, 'CGPA')
